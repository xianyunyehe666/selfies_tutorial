# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
# uncomment this if you try the tutorial and end up with low-quality images
# IPythonConsole.ipython_useSVG=True

# %%
import time
print(time.asctime()) # doctest: IGNORE
# Out:
# Wed Dec 11 21:19:40 2024

# %%
m = Chem.MolFromSmiles('C(OC(=O)Cl)I')
m

# %%
Chem.CanonSmiles('c1ccccc1')
# Out:
# 'c1ccccc1'

# %%
m1 = Chem.MolFromSmiles('ClC/1=C/CCCCN1')
m1

# %%
Chem.MolFromSmiles('CC1CCCO[C@@]12CCCCO2')
